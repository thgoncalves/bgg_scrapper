# %% [markdown]
# # BGG Scraper
#
# This script is optimized to collect information from BGG web pages using their XMLAPI2 API.
#
# All games are displayed on a search page provided by the site. We use that as a starting point for the scraper. With games ID (witch are unique) we are able to collect even more information about them, specialy the Statistics data.
#
# The API alow us to query for more than 1 game, making the extraction incredibly more efficient, restricted only by the size of the URL itself. There for, we have to break the URLs into smaller groups. In this case, 500 games per request is enought to get the date without overloading the downloaded string.

# %%
"""Boardgame class"""

class BoardGame(object):
    """Object containing information about a boardgame"""
    
    def __init__(self, data):
        self._data = data
    
    def __len__(self):
        return self._data_len
    
    def __repr__(self):
        return("Boardgame(" + self.name + ")")
    
    def data(self):
        """Internal data dictionary"""
        return self._data
    
    @property
    def item(self):
        """Internal dictionary of 'item'"""
        return self._data #['items']['item']
        
    @property
    def statistics(self):
        """Internal dictionary of 'statistics'"""
        return self.item['statistics']
    
    @property
    def name(self):
        """object name"""
        try:
            return str(self.item['name']['@value'])
        except:
            return str(self.item['name'][0]['@value'])

            
    @property
    def id(self):
        """BGG ID"""
        return self.item['@id']
        
    @property
    def description(self):
        """Game description"""
        return self.item['description']
        
    @property
    def year_published(self):
        """Year of publication"""
        try:
            temp = int(self.item['yearpublished']['@value'])
        except:
            temp = 0
        
        return temp
        
    @property
    def min_players(self):
        """Minimum number of players, according to publisher"""
        try:
            temp = int(self.item['minplayers']['@value'])
        except:
            temp = 0
        
        return temp
        
    @property
    def max_players(self):
        """Maximum number of players, according to publisher"""
        try:
            temp = int(self.item['maxplayers']['@value'])
        except:
            temp = 0
        
        return temp

    @property
    def suggested_players(self):
        """BGG users suggested best player count"""
        poll = self.item['poll']
        poll_names = [ii['@name'] for ii in poll]
        poll = poll[poll_names.index('suggested_numplayers')]['results']
        
        best_player_cnt = {}
        def _get_best_num_players(index):
            numplay = poll[index]['@numplayers']
            best_votes = poll[index]['result'][0]['@numvotes']
            best_player_cnt[numplay] = int(best_votes)
        
        for x in range(len(poll)):
            _get_best_num_players(x) 
        max_votes = max(list(best_player_cnt.values()))
        
        suggested_players = [count for count, votes in best_player_cnt.items() if votes == max_votes][0]
                
        return suggested_players
    
    @property
    def min_age(self):
        """Publisher defined minimum age"""
        try:
            temp = int(self.item['minage']['@value'])
        except:
            temp = 0
        
        return temp
    
    @property
    def suggested_player_age(self):
        """BGG users suggested minimum age"""
        poll = self.item['poll']
        poll_names = [ii['@name'] for ii in poll]
        poll = poll[poll_names.index('suggested_playerage')]['results']['result']
        
        best_player_age = {}
        def _get_best_age_players(index):
            age = poll[index]['@value']
            num_votes = poll[index]['@numvotes']
            best_player_age[age] = int(num_votes)
        
        for x in range(len(poll)):
            _get_best_age_players(x)
        
        max_votes = max(list(best_player_age.values()))
        
        suggested_age = [count for count, votes in best_player_age.items() if votes == max_votes][0]
        
        return int(suggested_age)
    
    @property
    def language_dependence(self):
        """BGG users suggested language dependence"""
        poll = self.item['poll']
        poll_names = [ii['@name'] for ii in poll]
        poll = poll[poll_names.index('language_dependence')]['results']['result']
        
        voted_language_dependence = {}
        def _get_language_requirements(index):
            language_level = poll[index]['@value']
            num_votes = poll[index]['@numvotes']
            voted_language_dependence[language_level] = int(num_votes)
        
        for x in range(len(poll)):
            _get_language_requirements(x)
            
        max_votes = max(list(voted_language_dependence.values()))
        language_requirement = [count for count, votes in voted_language_dependence.items() if votes == max_votes][0]
        
        return language_requirement
        
    @property
    def playing_time(self):
        """BGG suggested playing time"""
        return int(self.item['playingtime']['@value'])
        
    @property
    def min_play_time(self):
        """Publisher defined minimum play time"""
        return int(self.item['minplaytime']['@value'])
        
    @property
    def max_play_time(self):
        """Publisher defined maximum play time"""
        return int(self.item['maxplaytime']['@value'])
        
    @property
    def categories(self):
        """List of game categories (i.e. theme)"""
        link = self.item['link']
        link_names = [ii['@type'] for ii in link]
        names_index = [i for i, x in enumerate(link_names) if x == 'boardgamecategory']
        categories = [link[ii]['@value'] for ii in names_index]
        
        return categories
        
    @property
    def mechanics(self):
        """List of game categories (i.e. tile-laying, set collection)"""
        link = self.item['link']
        try:
            link_names = [ii['@type'] for ii in link]
            names_index = [i for i, x in enumerate(link_names) if x == 'boardgamemechanic']
            mechanics = [link[ii]['@value'] for ii in names_index]
        except:
            link_names = 'NEDD A FIX'
        return mechanics
        
    @property
    def game_family(self):
        """List of game families (i.e. Kickstarter, Made in Canda)"""
        link = self.item['link']
        link_names = [ii['@type'] for ii in link]
        names_index = [i for i, x in enumerate(link_names) if x == 'boardgamefamily']
        family = [link[ii]['@value'] for ii in names_index]
        
        return family
        
    @property
    def implementations(self):
        """Does game implement another? (e.g. Pandemic: Legacy re-implements Pandemic)"""
        link = self.item['link']
        link_names = [ii['@type'] for ii in link]
        names_index = [i for i, x in enumerate(link_names) if x == 'boardgameimplementation']
        implements = [link[ii]['@value'] for ii in names_index]
        
        return implements
        
    @property
    def designers(self):
        """List of game's designers"""
        link = self.item['link']
        link_names = [ii['@type'] for ii in link]
        names_index = [i for i, x in enumerate(link_names) if x == 'boardgamedesigner']
        designers = [link[ii]['@value'] for ii in names_index]
        
        return designers
        
    @property
    def artists(self):
        """List of game's artists"""
        link = self.item['link']
        link_names = [ii['@type'] for ii in link]
        names_index = [i for i, x in enumerate(link_names) if x == 'boardgameartist']
        artists = [link[ii]['@value'] for ii in names_index]
        
        return artists
        
    @property
    def publishers(self):
        """List of game's Publisher"""
        link = self.item['link']
        try:
            link_names = [ii['@type'] for ii in link]
            names_index = [i for i, x in enumerate(link_names) if x == 'boardgamepublisher']
            publishers = [link[ii]['@value'] for ii in names_index]
        except:
            link_names = link[0]['@type']
            names_index = [i for i, x in enumerate(link_names) if x == 'boardgamepublisher']
            publishers = link[0]['@value']
        
        return publishers
    
    
    
    
        
    @property
    def rank(self):
        """Dictionary of games various ranks (e.g. Overall, Strategy Games, Family, etc.)"""

        rankings = self.statistics['ratings']['ranks']['rank']
        
        num_rank_names = sum([i == '@name'for i in rankings])
        
        if num_rank_names == 1:
            if type(rankings) is int:
                ranks = {'boardgame':float(rankings['@value'])}
            else:
                ranks = {'boardgame': 0}
        else:
            rank_names = [ii['@name'] for ii in rankings]
            
            ranks = {}
            def _get_ranking(name):
                name_rank = rank_names.index(name)
                if type(rankings[name_rank]['@value']) is int:
                    ranks[name] = int(rankings[name_rank]['@value'])
                else:
                    ranks[name] = 0
            for ii in rank_names:
                _get_ranking(ii)
        
        return ranks
    
    @property
    def ranks_bayes(self):
        """Dictionary of games various bayesian ranks (e.g. Overall, Strategy Games, Family, etc.)"""
        rankings = self.statistics['ratings']['ranks']['rank']
        num_rank_names = sum([i == '@name' for i in rankings])
        
        if num_rank_names == 1:
            ranks = {'boardgame':float(rankings['@bayesaverage'])}
        
        else:
            rank_names = [ii['@name'] for ii in rankings]
            
            ranks = {}
            def _get_bayes_ranking(name):
                name_rank = rank_names.index(name)
                ranks[name] = float(rankings[name_rank]['@bayesaverage'])
            
            for ii in rank_names:
                _get_bayes_ranking(ii)
        
        return ranks
    
    @property
    def users_rated(self):
        """Number of BGG users who've rated game"""
        return int(self.statistics['ratings']['usersrated']['@value'])
        
    @property
    def avg_rating(self):
        """Average BGG user rating (10-point scale)"""
        return float(self.statistics['ratings']['average']['@value'])
        
    @property
    def bayes_avg_rating(self):
        """Average BGG user's bayesian rating (10-point scale)"""
        return float(self.statistics['ratings']['bayesaverage']['@value'])
    
    @property
    def stdev_rating(self):
        """Standard deviation of BGG user rating (10-point scale)"""
        return float(self.statistics['ratings']['stddev']['@value'])
    
    @property
    def median_rating(self):
        """Median BGG user rating (10-point scale)"""
        return float(self.statistics['ratings']['median']['@value'])
        
    @property
    def num_owned(self):
        """Number of BGG users who own this game"""
        return  int(self.statistics['ratings']['owned']['@value'])
        
    @property
    def num_trading(self):
        """Number of copies being traded on BGG marketplace"""
        return int(self.statistics['ratings']['trading']['@value'])
        
    @property
    def num_wanting(self):
        """Number of BGG users who want to buy this game"""
        return int(self.statistics['ratings']['wanting']['@value'])
        
    @property
    def num_wishing(self):
        """Number of BGG users who wish they had this game"""
        return int(self.statistics['ratings']['wishing']['@value'])
        
    @property
    def num_comments(self):
        """Number of comments about the game"""
        return int(self.statistics['ratings']['numcomments']['@value'])
        
    @property
    def num_weights(self):
        """Number of BGG users who have assigned the game a weight (5-point scale)"""
        return int(self.statistics['ratings']['numweights']['@value'])
        
    @property
    def avg_weight(self):
        """Average weight assigned by BGG users (5-point scale)"""
        return float(self.statistics['ratings']['averageweight']['@value'])

# %% [markdown]
# ## Import necessary packages
#
# First, import all packages necessary for this extraction.

# %%
"""Main boardgame script file"""

import pickle
import pandas as pd
import time 
# from urllib2 import urlopen
from urllib.request import urlopen
import requests
import re
from bs4 import BeautifulSoup as BS
import xmltodict
import time
import progressbar
import sys
import numpy as np
import pyodbc
import json
import math
from tqdm import tqdm

# %%
total_timer_start = time.time()

# %% [markdown]
# ## Download pages from the internet (not yet games details, just ID and Name)

# %% [markdown]
# This function is used to download the Game ID from BGG search page. This will be helpful to collect information about the game itself later on, based on the IDs.
#
# The Game name is also downloaded, but in the end, it is not used.

# %%
def pull_game_names(page):
    """Get all game names and IDs from a page of BGG website.
    
    Description:
        Scrapes Board Game Geek website games in order of rank.
        Returns a dictionary of games titles:BGG ID, given a page number
        Games are listed in increments of 50
        
    inputs:
        page (int): Page number (starts at 1)
        
    returns:
        game_list (dict): {Name:ID}
    """
    url = 'https://boardgamegeek.com/browse/boardgame/page/{}'.format(page)
    bgg_page = urlopen(url)

    my_bytes = bgg_page.read()
    url_text = my_bytes.decode("utf8")
    bgg_page.close()
    url_text = BS(url_text, 'html.parser')
    
    games = url_text.find_all("td", class_="collection_objectname")
    
    def get_game_name(item):
        game_name = item.findNext('a').text
        return(game_name)
        
    def get_game_ID(item):
        game_link_id = str(item.findNext('a'))
        game_link_id = re.search('[0-9]{1,7}', game_link_id).group(0)
        return(int(game_link_id))
    
    game_list = {get_game_name(ii):get_game_ID(ii) for ii in games}
    

    return(game_list)

# %%
def list_to_boardgame_class(num_pages):

    """Return list of Boardgame Objects
    
    Description:
        Calls pull_game_names() and boardgame_info(), passing information to 
        Boardgame() class, and returns a list of all class objects.
     
    Input:
        num_pages (int): Number of pages of games (100 per page)
    
    Returns:
        all_games (list): List of each game as a Boardgame object
    
    """
    ## Get boardgame names and IDs for the top 1000 games (10 pages)
    game_list = [pull_game_names(ii) for ii in progressbar.log_progress(range(1, num_pages + 1),'Game List')]
    game_IDs = [x for y in list([ii.values() for ii in game_list]) for x in y]
    ## Connect IDs with BGG API, get game information

    return(game_IDs) #(game_list, game_IDs)

# %% [markdown]
# ## Procedure Start
#
# We start here by going througth the pages and collecting the BoardGame ID. Then, we append that to a list with all games IDs
#
# ### Feedback
# Sometimes scripts run for a long time without stopping, specialy with URL request, since those rely on the connection itself. Or even for long loops.
# In this case, both things happen, so I added a ProgressBar as a way to know if the script is really running correctly.
#
# The user feedback function is called **progressbar.log_progress(list, string)**

# %%
start = time.time()

num_pages = 1050

if __name__ == "__main__":
    ## Get boardgame names and IDs for the top xxx games (100 * num_pages)
    all_games_IDs = list_to_boardgame_class(num_pages)
    print("Scraping complete")

end = time.time()
print('Elapsed time: ', time.strftime("%H:%M:%S", time.gmtime(end-start)))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1050)))
# Scraping complete
# Elapsed time:  01:13:33

# %%
len(all_games_IDs)
# Out:
# 104957

# %% [markdown]
# ## Building URL with 500 games to increase download performance

# %%
all_games_IDs_backup = all_games_IDs.copy()

# %%
ids_already_processed = []
list_of_urls = []
number_of_games_on_search = 400
search_len = math.ceil(len(all_games_IDs)/number_of_games_on_search) #math.ceil will round up to the next integer
if search_len < 1:
    search_len = 1
print('Number of searches:', search_len)
# Out:
# Number of searches: 263

# %%
for i in range(int(search_len)):
    url = 'https://boardgamegeek.com/xmlapi2/thing?id='
    for ID in all_games_IDs[:number_of_games_on_search]:
            url = url + str(ID) + ','
            ids_already_processed.append(ID)
            all_games_IDs.remove(ID)
    url= url[:-1] + '&stats=1'
    list_of_urls.append(url)

# %%
print('Number of XMLs is', len(list_of_urls), ',with a total of ',len(ids_already_processed),'games')
# Out:
# Number of XMLs is 263 ,with a total of  104957 games

# %% [markdown]
# ## Download game details
#
# If game IDs collected and URLs group and ready, we can finally download the XMLs from BGG Website

# %% [markdown]
# ### First try
# Sometimes the page returns an error for a few requests. Since this takes a long time to finish, I divided this in two parts
#
# 1) First, download pages from the web and store in a list
#     a) While doing that, check for errors in the download and store on another list for a second retry
#
# 2) With everything local, parse the XMLL. This will avoid having to download everything again in search for errors

# %% [markdown]
# ### Checkpoint

# %%
save_list_of_urls = list_of_urls.copy()

# %%
def download_bg_details(list_of_urls_to_download):
    attempts = 0
    for url in progressbar.log_progress(list_of_urls_to_download, 'Downloading Pages (Multiple Games Details)'):
            page = requests.get(url)
            if page.status_code == requests.codes.ok:
                successful_requests.append(page)
            else:
                bad_url_request.append(url)
    if len(bad_url_request) != 0 and attempts <=10:
        download_bg_details(bad_url_request)
        attempts += 1
    return successful_requests

# %%
first_half = int(round(len(list_of_urls)/2,0))
second_half = int((len(list_of_urls) - first_half)*-1)

# %%
start = time.time()
bad_url_request = []
successful_requests = []

downloaded_xmls = download_bg_details(list_of_urls[:first_half])
downloaded_xmls = download_bg_details(list_of_urls[:second_half])

end = time.time()
print('Elapsed time: ', time.strftime("%H:%M:%S", time.gmtime(end-start)))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=132)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=132)))
# Elapsed time:  00:32:11

# %%
dup = []
unique = []
for item in downloaded_xmls:
    if item not in unique:
        unique.append(item)
    else:
        dup.append(item)
len(dup)
# Out:
# 0

# %%
backup_of_downloads = downloaded_xmls.copy

# %% [markdown]
# ## Breaking down the XMLs received into a list with BoardGame objects

# %%
start = time.time()
flatted_list = []

for item in progressbar.log_progress(downloaded_xmls, 'Pages on XML'):
    page_xml = xmltodict.parse(item.content)
    for each_game in page_xml['items']['item']:
        temp = BoardGame(each_game)
        flatted_list.append(temp)
end = time.time()
print('Elapsed time: ', time.strftime("%H:%M:%S", time.gmtime(end-start)))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=264)))
# Elapsed time:  00:05:29

# %% [markdown]
# ## Build DataFrame
#
# Finaly we build the DataFrame of all games. This process is taking very long to complete. Improvements may be necessary.

# %%
lst = flatted_list
all_games = lst[:]
bg_df = pd.DataFrame()

bg_df = pd.DataFrame()
bg_df['Name'] = [i.name for i in progressbar.log_progress(flatted_list, 'Scanning Name')]
bg_df['ID'] = [i.id for i in progressbar.log_progress(flatted_list, 'Scanning ID')] 
bg_df['Publisher'] = [i.publishers[0] for i in progressbar.log_progress(flatted_list, 'Scanning Publishers')]
bg_df['Minimum Players'] = [i.min_players for i in progressbar.log_progress(flatted_list, 'Scanning Min Players')]
bg_df['Max Players'] = [i.max_players for i in progressbar.log_progress(flatted_list, 'Scanning Max Players')]
bg_df['Num_Ratings'] = [i.users_rated for i in progressbar.log_progress(flatted_list, 'Scanning Num Ratings')]
bg_df['Avg_Rating'] = [i.avg_rating for i in progressbar.log_progress(flatted_list, 'Scanning Ratings')]
bg_df['Bayes_Avg_Rating'] = [i.bayes_avg_rating for i in progressbar.log_progress(flatted_list, 'Scanning Bayes Rating')]
bg_df['Avg_Weight'] = [i.avg_weight for i in progressbar.log_progress(flatted_list, 'Scanning AVG Weight')]
bg_df['StDev_Rating'] = [i.stdev_rating for i in progressbar.log_progress(flatted_list, 'Scanning StDev Rating')]
bg_df['Num_Owned'] = [i.num_owned for i in progressbar.log_progress(flatted_list, 'Scanning Num Owned')]
bg_df['Num_Comments'] = [i.num_comments for i in progressbar.log_progress(flatted_list, 'Scanning Num Comments')]
bg_df['Num_Trading'] = [i.num_trading for i in progressbar.log_progress(flatted_list, 'Scanning Num Tradings')]
bg_df['Num_Wanting'] = [i.num_wanting for i in progressbar.log_progress(flatted_list, 'Scanning Num Waiting')]
bg_df['Num_Wishing'] = [i.num_wishing for i in progressbar.log_progress(flatted_list, 'Scanning Num Wishing')]
bg_df['Num_Weights'] = [i.num_weights for i in progressbar.log_progress(flatted_list, 'Scanning Num weights')]
bg_df['Year'] = [i.year_published for i in progressbar.log_progress(flatted_list, 'Scanning Year Published')]

## Rating
bg_df['Num_Ratings'] = [i.users_rated for i in progressbar.log_progress(all_games, 'Scanning Num Ratings')]
bg_df['Avg_Rating'] = [i.avg_rating for i in progressbar.log_progress(all_games, 'Scanning Ratings')]
bg_df['Bayes_Avg_Rating'] = [i.bayes_avg_rating for i in progressbar.log_progress(all_games, 'Scanning Bayes Rating')]
bg_df['Avg_Weight'] = [i.avg_weight for i in progressbar.log_progress(all_games, 'Scanning AVG Weight')]
bg_df['StDev_Rating'] = [i.stdev_rating for i in progressbar.log_progress(all_games, 'Scanning StDev Rating')]

## Players
try:
    bg_df['Pub_Min_Age'] = [i.min_age for i in progressbar.log_progress(all_games, 'Publisher Min Age')]
except:
    bg_df['Pub_Min_Age'] = 0


BGG_Min_Age = []
for i in all_games:
    try:
        BGG_Min_Age.append(i.suggested_player_age)
    except:
        BGG_Min_Age.append(np.nan)

bg_df['BGG_Min_Age'] = BGG_Min_Age

try:
    bg_df['Pub_Min_Players'] = [i.min_players for i in progressbar.log_progress(all_games, 'Publisher Min Players')]
except:
    bg_df['Pub_Min_Players'] = 0

try:
    bg_df['Pub_Max_Players'] = [i.max_players for i in progressbar.log_progress(all_games, 'Publisher Max Players')]
except:
    bg_df['Pub_Max_Players'] = 0

BGG_Num_Players = []
for i in all_games:
    try:
        BGG_Num_Players.append(i.suggested_players)
    except:
        BGG_Num_Players.append(np.nan)

bg_df['BGG_Num_Players'] = BGG_Num_Players
try:
    bg_df['Play_Time'] = [i.playing_time for i in progressbar.log_progress(all_games, 'Scanning Play Time')]
except:
    bg_df['Play_Time'] = 0

## Ownership & Community Engagement
bg_df['Num_Owned'] = [i.num_owned for i in progressbar.log_progress(all_games, 'Scanning Num Owned')]
bg_df['Num_Comments'] = [i.num_comments for i in progressbar.log_progress(all_games, 'Scanning Num Comments')]
bg_df['Num_Trading'] = [i.num_trading for i in progressbar.log_progress(all_games, 'Scanning Num Tradings')]
bg_df['Num_Wanting'] = [i.num_wanting for i in progressbar.log_progress(all_games, 'Scanning Num Waiting')]
bg_df['Num_Wishing'] = [i.num_wishing for i in progressbar.log_progress(all_games, 'Scanning Num Wishing')]
bg_df['Num_Weights'] = [i.num_weights for i in progressbar.log_progress(all_games, 'Scanning Num weights')]

### Ranks
rank_categories = []
for i in progressbar.log_progress(all_games, 'Rank categories'):
    rank_categories.append(list(i.rank.keys()))

unique_rank_categories = list(set([i for j in progressbar.log_progress(rank_categories, 'Rank categories') for i in j]))
rank_columns = ['Name', 'ID'] + unique_rank_categories
major_rank_df = pd.DataFrame(columns = rank_columns)

for game in progressbar.log_progress(all_games, 'Rank'):
    rank_data = game.rank
    rank_data['Name'] = game.name
    rank_data['ID'] = game.id
    minor_rank_df = pd.DataFrame(rank_data, index=[0], columns = rank_columns)
    major_rank_df = major_rank_df.append(minor_rank_df)
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))

# %%
bg_df_backup = bg_df.copy()

# %%
bg_df = bg_df.merge(major_rank_df, on = ['Name', 'ID'])

# %%
bg_df
# Out:
#                                                      Name      ID  \
# 0                                              Gloomhaven  174430
# 1                                              Gloomhaven  174430
# 2                                              Gloomhaven  174430
# 3                                              Gloomhaven  174430
# 4                               Pandemic Legacy: Season 1  161936
# 5                               Pandemic Legacy: Season 1  161936
# 6                               Pandemic Legacy: Season 1  161936
# 7                               Pandemic Legacy: Season 1  161936
# 8           Through the Ages: A New Story of Civilization  182028
# 9           Through the Ages: A New Story of Civilization  182028
# 10          Through the Ages: A New Story of Civilization  182028
# 11          Through the Ages: A New Story of Civilization  182028
# 12                                      Terraforming Mars  167791
# 13                                      Terraforming Mars  167791
# 14                                      Terraforming Mars  167791
# 15                                      Terraforming Mars  167791
# 16                                      Twilight Struggle   12333
# 17                                      Twilight Struggle   12333
# 18                                      Twilight Struggle   12333
# 19                                      Twilight Struggle   12333
# 20                                   Star Wars: Rebellion  187645
# 21                                   Star Wars: Rebellion  187645
# 22                                   Star Wars: Rebellion  187645
# 23                                   Star Wars: Rebellion  187645
# 24                                           Gaia Project  220308
# 25                                           Gaia Project  220308
# 26                                           Gaia Project  220308
# 27                                           Gaia Project  220308
# 28                                                 Scythe  169786
# 29                                                 Scythe  169786
# ...                                                   ...     ...
# 211682                                        Pizza Party   68097
# 211683                                        Pizza Party   68097
# 211684                                       O' PenzedoR!   68104
# 211685                                       O' PenzedoR!   68104
# 211686                                       O' PenzedoR!   68104
# 211687                                       O' PenzedoR!   68104
# 211688  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211689  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211690  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211691  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211692             Super Sadistic Advanced Empire Builder   68119
# 211693             Super Sadistic Advanced Empire Builder   68119
# 211694             Super Sadistic Advanced Empire Builder   68119
# 211695             Super Sadistic Advanced Empire Builder   68119
# 211696                                     ASL Annual '92   68122
# 211697                                     ASL Annual '92   68122
# 211698                                     ASL Annual '92   68122
# 211699                                     ASL Annual '92   68122
# 211700                                Assault of the Dead   68137
# 211701                                Assault of the Dead   68137
# 211702                                Assault of the Dead   68137
# 211703                                Assault of the Dead   68137
# 211704                              The Green and The Tan   68138
# 211705                              The Green and The Tan   68138
# 211706                              The Green and The Tan   68138
# 211707                              The Green and The Tan   68138
# 211708                                 UNO: Kung Fu Panda   68140
# 211709                                 UNO: Kung Fu Panda   68140
# 211710                                 UNO: Kung Fu Panda   68140
# 211711                                 UNO: Kung Fu Panda   68140
#
#                           Publisher  Minimum Players  Max Players  \
# 0                 Cephalofair Games                1            4
# 1                 Cephalofair Games                1            4
# 2                 Cephalofair Games                1            4
# 3                 Cephalofair Games                1            4
# 4                 Z-Man Games, Inc.                2            4
# 5                 Z-Man Games, Inc.                2            4
# 6                 Z-Man Games, Inc.                2            4
# 7                 Z-Man Games, Inc.                2            4
# 8               Czech Games Edition                2            4
# 9               Czech Games Edition                2            4
# 10              Czech Games Edition                2            4
# 11              Czech Games Edition                2            4
# 12                        FryxGames                1            5
# 13                        FryxGames                1            5
# 14                        FryxGames                1            5
# 15                        FryxGames                1            5
# 16                        GMT Games                2            2
# 17                        GMT Games                2            2
# 18                        GMT Games                2            2
# 19                        GMT Games                2            2
# 20             Fantasy Flight Games                2            4
# 21             Fantasy Flight Games                2            4
# 22             Fantasy Flight Games                2            4
# 23             Fantasy Flight Games                2            4
# 24                 Feuerland Spiele                1            4
# 25                 Feuerland Spiele                1            4
# 26                 Feuerland Spiele                1            4
# 27                 Feuerland Spiele                1            4
# 28                 Stonemaier Games                1            5
# 29                 Stonemaier Games                1            5
# ...                             ...              ...          ...
# 211682  Ideal School Supply Company                2            6
# 211683  Ideal School Supply Company                2            6
# 211684                Pavillon Noir                3            5
# 211685                Pavillon Noir                3            5
# 211686                Pavillon Noir                3            5
# 211687                Pavillon Noir                3            5
# 211688     Patrick Stephens Limited                2            0
# 211689     Patrick Stephens Limited                2            0
# 211690     Patrick Stephens Limited                2            0
# 211691     Patrick Stephens Limited                2            0
# 211692             (Self-Published)                2            8
# 211693             (Self-Published)                2            8
# 211694             (Self-Published)                2            8
# 211695             (Self-Published)                2            8
# 211696      The Avalon Hill Game Co                2            2
# 211697      The Avalon Hill Game Co                2            2
# 211698      The Avalon Hill Game Co                2            2
# 211699      The Avalon Hill Game Co                2            2
# 211700             (Self-Published)                3            5
# 211701             (Self-Published)                3            5
# 211702             (Self-Published)                3            5
# 211703             (Self-Published)                3            5
# 211704             (Self-Published)                2            2
# 211705             (Self-Published)                2            2
# 211706             (Self-Published)                2            2
# 211707             (Self-Published)                2            2
# 211708                       Mattel                2           10
# 211709                       Mattel                2           10
# 211710                       Mattel                2           10
# 211711                       Mattel                2           10
#
#         Num_Ratings  Avg_Rating  Bayes_Avg_Rating  Avg_Weight  StDev_Rating  \
# 0             23504     8.91228           8.61315      3.7753       1.60192
# 1             23504     8.91228           8.61315      3.7753       1.60192
# 2             23504     8.91228           8.61315      3.7753       1.60192
# 3             23504     8.91228           8.61315      3.7753       1.60192
# 4             30370     8.64675           8.49226      2.8318       1.61203
# 5             30370     8.64675           8.49226      2.8318       1.61203
# 6             30370     8.64675           8.49226      2.8318       1.61203
# 7             30370     8.64675           8.49226      2.8318       1.61203
# 8             15179     8.54243           8.26341      4.3657       1.49137
# 9             15179     8.54243           8.26341      4.3657       1.49137
# 10            15179     8.54243           8.26341      4.3657       1.49137
# 11            15179     8.54243           8.26341      4.3657       1.49137
# 12            36736     8.40232           8.23708      3.2313       1.35854
# 13            36736     8.40232           8.23708      3.2313       1.35854
# 14            36736     8.40232           8.23708      3.2313       1.35854
# 15            36736     8.40232           8.23708      3.2313       1.35854
# 16            33857     8.32508           8.17631      3.5645       1.58734
# 17            33857     8.32508           8.17631      3.5645       1.58734
# 18            33857     8.32508           8.17631      3.5645       1.58734
# 19            33857     8.32508           8.17631      3.5645       1.58734
# 20            16091     8.44952           8.16307      3.6729       1.37798
# 21            16091     8.44952           8.16307      3.6729       1.37798
# 22            16091     8.44952           8.16307      3.6729       1.37798
# 23            16091     8.44952           8.16307      3.6729       1.37798
# 24             8593     8.56949           8.12296      4.3012       1.42125
# 25             8593     8.56949           8.12296      4.3012       1.42125
# 26             8593     8.56949           8.12296      4.3012       1.42125
# 27             8593     8.56949           8.12296      4.3012       1.42125
# 28            37941     8.29311           8.12183      3.3705       1.42014
# 29            37941     8.29311           8.12183      3.3705       1.42014
# ...             ...         ...               ...         ...           ...
# 211682            2     4.75000           0.00000      0.0000       0.25000
# 211683            2     4.75000           0.00000      0.0000       0.25000
# 211684           12     5.20833           0.00000      1.0000       1.61321
# 211685           12     5.20833           0.00000      1.0000       1.61321
# 211686           12     5.20833           0.00000      1.0000       1.61321
# 211687           12     5.20833           0.00000      1.0000       1.61321
# 211688            1     7.00000           0.00000      0.0000       0.00000
# 211689            1     7.00000           0.00000      0.0000       0.00000
# 211690            1     7.00000           0.00000      0.0000       0.00000
# 211691            1     7.00000           0.00000      0.0000       0.00000
# 211692            0     0.00000           0.00000      0.0000       0.00000
# 211693            0     0.00000           0.00000      0.0000       0.00000
# 211694            0     0.00000           0.00000      0.0000       0.00000
# 211695            0     0.00000           0.00000      0.0000       0.00000
# 211696           54     7.75926           5.59330      4.7143       1.63509
# 211697           54     7.75926           5.59330      4.7143       1.63509
# 211698           54     7.75926           5.59330      4.7143       1.63509
# 211699           54     7.75926           5.59330      4.7143       1.63509
# 211700            0     0.00000           0.00000      3.0000       0.00000
# 211701            0     0.00000           0.00000      3.0000       0.00000
# 211702            0     0.00000           0.00000      3.0000       0.00000
# 211703            0     0.00000           0.00000      3.0000       0.00000
# 211704            1     5.50000           0.00000      0.0000       0.00000
# 211705            1     5.50000           0.00000      0.0000       0.00000
# 211706            1     5.50000           0.00000      0.0000       0.00000
# 211707            1     5.50000           0.00000      0.0000       0.00000
# 211708            4     5.00000           0.00000      0.0000       1.22474
# 211709            4     5.00000           0.00000      0.0000       1.22474
# 211710            4     5.00000           0.00000      0.0000       1.22474
# 211711            4     5.00000           0.00000      0.0000       1.22474
#
#            ...       strategygames  familygames  childrensgames  \
# 0          ...                   0          NaN             NaN
# 1          ...                   0          NaN             NaN
# 2          ...                   0          NaN             NaN
# 3          ...                   0          NaN             NaN
# 4          ...                   0          NaN             NaN
# 5          ...                   0          NaN             NaN
# 6          ...                   0          NaN             NaN
# 7          ...                   0          NaN             NaN
# 8          ...                   0          NaN             NaN
# 9          ...                   0          NaN             NaN
# 10         ...                   0          NaN             NaN
# 11         ...                   0          NaN             NaN
# 12         ...                   0          NaN             NaN
# 13         ...                   0          NaN             NaN
# 14         ...                   0          NaN             NaN
# 15         ...                   0          NaN             NaN
# 16         ...                   0          NaN             NaN
# 17         ...                   0          NaN             NaN
# 18         ...                   0          NaN             NaN
# 19         ...                   0          NaN             NaN
# 20         ...                   0          NaN             NaN
# 21         ...                   0          NaN             NaN
# 22         ...                   0          NaN             NaN
# 23         ...                   0          NaN             NaN
# 24         ...                   0          NaN             NaN
# 25         ...                   0          NaN             NaN
# 26         ...                   0          NaN             NaN
# 27         ...                   0          NaN             NaN
# 28         ...                   0          NaN             NaN
# 29         ...                   0          NaN             NaN
# ...        ...                 ...          ...             ...
# 211682     ...                 NaN          NaN             NaN
# 211683     ...                 NaN          NaN             NaN
# 211684     ...                 NaN          NaN             NaN
# 211685     ...                 NaN          NaN             NaN
# 211686     ...                 NaN          NaN             NaN
# 211687     ...                 NaN          NaN             NaN
# 211688     ...                 NaN          NaN             NaN
# 211689     ...                 NaN          NaN             NaN
# 211690     ...                 NaN          NaN             NaN
# 211691     ...                 NaN          NaN             NaN
# 211692     ...                 NaN          NaN             NaN
# 211693     ...                 NaN          NaN             NaN
# 211694     ...                 NaN          NaN             NaN
# 211695     ...                 NaN          NaN             NaN
# 211696     ...                 NaN          NaN             NaN
# 211697     ...                 NaN          NaN             NaN
# 211698     ...                 NaN          NaN             NaN
# 211699     ...                 NaN          NaN             NaN
# 211700     ...                 NaN          NaN             NaN
# 211701     ...                 NaN          NaN             NaN
# 211702     ...                 NaN          NaN             NaN
# 211703     ...                 NaN          NaN             NaN
# 211704     ...                 NaN          NaN             NaN
# 211705     ...                 NaN          NaN             NaN
# 211706     ...                 NaN          NaN             NaN
# 211707     ...                 NaN          NaN             NaN
# 211708     ...                 NaN          NaN             NaN
# 211709     ...                 NaN          NaN             NaN
# 211710     ...                 NaN          NaN             NaN
# 211711     ...                 NaN          NaN             NaN
#
#         boardgameaccessory  wargames  thematic  arcade  cgs  videogame  \
# 0                      NaN       NaN         0     NaN  NaN        NaN
# 1                      NaN       NaN         0     NaN  NaN        NaN
# 2                      NaN       NaN         0     NaN  NaN        NaN
# 3                      NaN       NaN         0     NaN  NaN        NaN
# 4                      NaN       NaN         0     NaN  NaN        NaN
# 5                      NaN       NaN         0     NaN  NaN        NaN
# 6                      NaN       NaN         0     NaN  NaN        NaN
# 7                      NaN       NaN         0     NaN  NaN        NaN
# 8                      NaN       NaN       NaN     NaN  NaN        NaN
# 9                      NaN       NaN       NaN     NaN  NaN        NaN
# 10                     NaN       NaN       NaN     NaN  NaN        NaN
# 11                     NaN       NaN       NaN     NaN  NaN        NaN
# 12                     NaN       NaN       NaN     NaN  NaN        NaN
# 13                     NaN       NaN       NaN     NaN  NaN        NaN
# 14                     NaN       NaN       NaN     NaN  NaN        NaN
# 15                     NaN       NaN       NaN     NaN  NaN        NaN
# 16                     NaN         0       NaN     NaN  NaN        NaN
# 17                     NaN         0       NaN     NaN  NaN        NaN
# 18                     NaN         0       NaN     NaN  NaN        NaN
# 19                     NaN         0       NaN     NaN  NaN        NaN
# 20                     NaN       NaN         0     NaN  NaN        NaN
# 21                     NaN       NaN         0     NaN  NaN        NaN
# 22                     NaN       NaN         0     NaN  NaN        NaN
# 23                     NaN       NaN         0     NaN  NaN        NaN
# 24                     NaN       NaN       NaN     NaN  NaN        NaN
# 25                     NaN       NaN       NaN     NaN  NaN        NaN
# 26                     NaN       NaN       NaN     NaN  NaN        NaN
# 27                     NaN       NaN       NaN     NaN  NaN        NaN
# 28                     NaN       NaN       NaN     NaN  NaN        NaN
# 29                     NaN       NaN       NaN     NaN  NaN        NaN
# ...                    ...       ...       ...     ...  ...        ...
# 211682                 NaN       NaN       NaN     NaN  NaN        NaN
# 211683                 NaN       NaN       NaN     NaN  NaN        NaN
# 211684                 NaN       NaN       NaN     NaN  NaN        NaN
# 211685                 NaN       NaN       NaN     NaN  NaN        NaN
# 211686                 NaN       NaN       NaN     NaN  NaN        NaN
# 211687                 NaN       NaN       NaN     NaN  NaN        NaN
# 211688                 NaN         0       NaN     NaN  NaN        NaN
# 211689                 NaN         0       NaN     NaN  NaN        NaN
# 211690                 NaN         0       NaN     NaN  NaN        NaN
# 211691                 NaN         0       NaN     NaN  NaN        NaN
# 211692                 NaN       NaN       NaN     NaN  NaN        NaN
# 211693                 NaN       NaN       NaN     NaN  NaN        NaN
# 211694                 NaN       NaN       NaN     NaN  NaN        NaN
# 211695                 NaN       NaN       NaN     NaN  NaN        NaN
# 211696                 NaN         0       NaN     NaN  NaN        NaN
# 211697                 NaN         0       NaN     NaN  NaN        NaN
# 211698                 NaN         0       NaN     NaN  NaN        NaN
# 211699                 NaN         0       NaN     NaN  NaN        NaN
# 211700                 NaN       NaN       NaN     NaN  NaN        NaN
# 211701                 NaN       NaN       NaN     NaN  NaN        NaN
# 211702                 NaN       NaN       NaN     NaN  NaN        NaN
# 211703                 NaN       NaN       NaN     NaN  NaN        NaN
# 211704                 NaN       NaN       NaN     NaN  NaN        NaN
# 211705                 NaN       NaN       NaN     NaN  NaN        NaN
# 211706                 NaN       NaN       NaN     NaN  NaN        NaN
# 211707                 NaN       NaN       NaN     NaN  NaN        NaN
# 211708                 NaN       NaN       NaN     NaN  NaN        NaN
# 211709                 NaN       NaN       NaN     NaN  NaN        NaN
# 211710                 NaN       NaN       NaN     NaN  NaN        NaN
# 211711                 NaN       NaN       NaN     NaN  NaN        NaN
#
#         commodore64
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 211682          NaN
# 211683          NaN
# 211684          NaN
# 211685          NaN
# 211686          NaN
# 211687          NaN
# 211688          NaN
# 211689          NaN
# 211690          NaN
# 211691          NaN
# 211692          NaN
# 211693          NaN
# 211694          NaN
# 211695          NaN
# 211696          NaN
# 211697          NaN
# 211698          NaN
# 211699          NaN
# 211700          NaN
# 211701          NaN
# 211702          NaN
# 211703          NaN
# 211704          NaN
# 211705          NaN
# 211706          NaN
# 211707          NaN
# 211708          NaN
# 211709          NaN
# 211710          NaN
# 211711          NaN
#
# [211712 rows x 39 columns]

# %%
bg_df = bg_df.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
bg_df
# Out:
#                                                      Name      ID  \
# 0                                              Gloomhaven  174430
# 4                               Pandemic Legacy: Season 1  161936
# 8           Through the Ages: A New Story of Civilization  182028
# 12                                      Terraforming Mars  167791
# 16                                      Twilight Struggle   12333
# 20                                   Star Wars: Rebellion  187645
# 24                                           Gaia Project  220308
# 28                                                 Scythe  169786
# 32                                    Great Western Trail  193738
# 36                     Twilight Imperium (Fourth Edition)  233078
# 40                                          Terra Mystica  120677
# 44                       War of the Ring (Second Edition)  115746
# 48                                The Castles of Burgundy   84876
# 52                                         7 Wonders Duel  173346
# 56                                          Spirit Island  162886
# 60                                      The 7th Continent  180263
# 64                                      Brass: Birmingham  224517
# 68                          Viticulture Essential Edition  183394
# 72                                            Puerto Rico    3076
# 76                                              Concordia  124361
# 80                           Arkham Horror: The Card Game  205637
# 84                              Caverna: The Cave Farmers  102794
# 88                                      Brass: Lancashire   28720
# 92                                 Mage Knight Board Game   96848
# 96                                               Agricola   31260
# 100                   Mansions of Madness: Second Edition  205059
# 104                                               Orléans  164928
# 108                                      A Feast for Odin  177736
# 112                                            Blood Rage  170216
# 116                                    Food Chain Magnate  175914
# ...                                                   ...     ...
# 211592                                             Ritual   68009
# 211596          Basic Action Super Heroes! Sci-Fi Edition   68017
# 211600                                    Five Star Final   68024
# 211604                                  Felix Farbenschaf   68030
# 211608                    Rechen-Piraten: Das Kartenspiel   68031
# 211612                                   Verhext nochmal!   68032
# 211616                           Dragon War: Gateways Set   68038
# 211620                                      Sword of Fire   68039
# 211624                                  Battle for Korsun   68046
# 211628                                         Dice Floor   68057
# 211632                                Star Fleet Scramble   68063
# 211636                 Battlefield Evolution: Pacific War   68065
# 211640                                  Finnish Civil War   68072
# 211644                                    Behind the Lens   68079
# 211648                                   Squiggle Connect   68084
# 211652                                               Gibs   68086
# 211656                                   Doubloon Dippity   68088
# 211660                                       Sink or Swim   68089
# 211664                                      Bed of Pearls   68092
# 211668                              Rolaweel Three in One   68094
# 211672                             Giggles Game of Action   68095
# 211676                                      Monkey Shines   68096
# 211680                                        Pizza Party   68097
# 211684                                       O' PenzedoR!   68104
# 211688  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211692             Super Sadistic Advanced Empire Builder   68119
# 211696                                     ASL Annual '92   68122
# 211700                                Assault of the Dead   68137
# 211704                              The Green and The Tan   68138
# 211708                                 UNO: Kung Fu Panda   68140
#
#                                 Publisher  Minimum Players  Max Players  \
# 0                       Cephalofair Games                1            4
# 4                       Z-Man Games, Inc.                2            4
# 8                     Czech Games Edition                2            4
# 12                              FryxGames                1            5
# 16                              GMT Games                2            2
# 20                   Fantasy Flight Games                2            4
# 24                       Feuerland Spiele                1            4
# 28                       Stonemaier Games                1            5
# 32                           eggertspiele                2            4
# 36                   Fantasy Flight Games                3            6
# 40                       Feuerland Spiele                2            5
# 44                             Ares Games                2            4
# 48                                   alea                2            4
# 52                       Repos Production                2            2
# 56      Greater Than Games (Fabled Nexus)                1            4
# 60                          Serious Poulp                1            4
# 64                                 Roxley                2            4
# 68                       Stonemaier Games                1            6
# 72                                   alea                3            5
# 76                              PD-Verlag                2            5
# 80                   Fantasy Flight Games                1            2
# 84                          Lookout Games                1            7
# 88                                 Roxley                2            4
# 92                                WizKids                1            4
# 96                          Lookout Games                1            5
# 100                  Fantasy Flight Games                1            5
# 104                             dlp games                2            4
# 108                      Feuerland Spiele                1            4
# 112                          CMON Limited                2            4
# 116                      Splotter Spellen                2            5
# ...                                   ...              ...          ...
# 211592                   (Self-Published)                2            0
# 211596                 Basic Action Games                0            0
# 211600                     Milton Bradley                0            5
# 211604                               HABA                2            4
# 211608                               HABA                2            4
# 211612                               HABA                2            4
# 211616                       RAK Graphics                2            6
# 211620                   (Self-Published)                2            2
# 211624                       Banana Games                2            2
# 211628                    (Web published)                2            3
# 211632                        nestorgames                2            2
# 211636                Mongoose Publishing                2            0
# 211640                   (Self-Published)                2            2
# 211644                          (Unknown)                1            0
# 211648                   RandomLine, Inc.                3            6
# 211652              The Game Crafter, LLC                2            5
# 211656                    Funhub Creative                2           10
# 211660                    Funhub Creative                2            4
# 211664                    Funhub Creative                2            4
# 211668                    Rosebud Art Co.                2            0
# 211672                    Rosebud Art Co.                1            0
# 211676        E. E. Fairchild Corporation                2            0
# 211680        Ideal School Supply Company                2            6
# 211684                      Pavillon Noir                3            5
# 211688           Patrick Stephens Limited                2            0
# 211692                   (Self-Published)                2            8
# 211696            The Avalon Hill Game Co                2            2
# 211700                   (Self-Published)                3            5
# 211704                   (Self-Published)                2            2
# 211708                             Mattel                2           10
#
#         Num_Ratings  Avg_Rating  Bayes_Avg_Rating  Avg_Weight  StDev_Rating  \
# 0             23504     8.91228           8.61315      3.7753      1.601920
# 4             30370     8.64675           8.49226      2.8318      1.612030
# 8             15179     8.54243           8.26341      4.3657      1.491370
# 12            36736     8.40232           8.23708      3.2313      1.358540
# 16            33857     8.32508           8.17631      3.5645      1.587340
# 20            16091     8.44952           8.16307      3.6729      1.377980
# 24             8593     8.56949           8.12296      4.3012      1.421250
# 28            37941     8.29311           8.12183      3.3705      1.420140
# 32            18302     8.28808           8.07636      3.6909      1.251350
# 36             6021     8.75469           8.06175      4.1752      1.535010
# 40            32077     8.19957           8.05233      3.9480      1.466770
# 44             9544     8.41695           8.02285      4.0564      1.538680
# 48            35851     8.13015           8.01235      3.0166      1.240730
# 52            39272     8.12677           7.99285      2.2297      1.163660
# 56             9757     8.38891           7.97867      3.9373      1.446270
# 60             8631     8.44554           7.95344      2.8659      1.593960
# 64             4815     8.63405           7.95232      3.8739      1.156050
# 68            16594     8.14955           7.92658      2.9222      1.241430
# 72            55810     8.04083           7.92631      3.2898      1.383100
# 76            19150     8.09685           7.92118      3.0876      1.188640
# 80            16664     8.22791           7.92054      3.3077      1.431470
# 84            23243     8.07825           7.91289      3.7873      1.352860
# 88            14647     8.11884           7.90638      3.8745      1.394450
# 92            23163     8.10591           7.89416      4.2635      1.617260
# 96            56402     7.99436           7.89228      3.6355      1.565990
# 100           15928     8.16405           7.88022      2.6678      1.433350
# 104           15394     8.08563           7.87587      3.0802      1.163920
# 108           10642     8.17832           7.85340      3.8229      1.347030
# 112           24863     8.03803           7.85112      2.8875      1.396530
# 116            9311     8.18605           7.84970      4.1957      1.546400
# ...             ...         ...               ...         ...           ...
# 211592            3     5.83333           0.00000      2.0000      3.423770
# 211596            0     0.00000           0.00000      0.0000      0.000000
# 211600            0     0.00000           0.00000      0.0000      0.000000
# 211604            7     6.27143           0.00000      1.0000      1.562700
# 211608            3     6.33333           0.00000      0.0000      0.471405
# 211612            3     3.00000           0.00000      0.0000      0.816497
# 211616            0     0.00000           0.00000      0.0000      0.000000
# 211620            4     5.50000           0.00000      1.0000      2.958040
# 211624            9     6.83333           0.00000      1.2500      1.763830
# 211628            2     6.00000           0.00000      2.0000      0.000000
# 211632            8     7.06250           0.00000      2.0000      1.073470
# 211636            3     7.66667           0.00000      0.0000      0.471405
# 211640           11     7.31818           0.00000      2.0000      0.805457
# 211644            0     0.00000           0.00000      0.0000      0.000000
# 211648            0     0.00000           0.00000      0.0000      0.000000
# 211652            2     7.75000           0.00000      1.0000      2.250000
# 211656            3     1.16667           0.00000      1.0000      0.235702
# 211660            6     3.16667           0.00000      1.0000      2.192160
# 211664            3     4.00000           0.00000      1.0000      2.160250
# 211668            0     0.00000           0.00000      0.0000      0.000000
# 211672            0     0.00000           0.00000      0.0000      0.000000
# 211676            0     0.00000           0.00000      0.0000      0.000000
# 211680            2     4.75000           0.00000      0.0000      0.250000
# 211684           12     5.20833           0.00000      1.0000      1.613210
# 211688            1     7.00000           0.00000      0.0000      0.000000
# 211692            0     0.00000           0.00000      0.0000      0.000000
# 211696           54     7.75926           5.59330      4.7143      1.635090
# 211700            0     0.00000           0.00000      3.0000      0.000000
# 211704            1     5.50000           0.00000      0.0000      0.000000
# 211708            4     5.00000           0.00000      0.0000      1.224740
#
#            ...       strategygames  familygames  childrensgames  \
# 0          ...                   0          NaN             NaN
# 4          ...                   0          NaN             NaN
# 8          ...                   0          NaN             NaN
# 12         ...                   0          NaN             NaN
# 16         ...                   0          NaN             NaN
# 20         ...                   0          NaN             NaN
# 24         ...                   0          NaN             NaN
# 28         ...                   0          NaN             NaN
# 32         ...                   0          NaN             NaN
# 36         ...                   0          NaN             NaN
# 40         ...                   0          NaN             NaN
# 44         ...                 NaN          NaN             NaN
# 48         ...                   0          NaN             NaN
# 52         ...                   0          NaN             NaN
# 56         ...                   0          NaN             NaN
# 60         ...                 NaN          NaN             NaN
# 64         ...                   0          NaN             NaN
# 68         ...                   0          NaN             NaN
# 72         ...                   0          NaN             NaN
# 76         ...                   0          NaN             NaN
# 80         ...                 NaN          NaN             NaN
# 84         ...                   0          NaN             NaN
# 88         ...                   0          NaN             NaN
# 92         ...                   0          NaN             NaN
# 96         ...                   0          NaN             NaN
# 100        ...                 NaN          NaN             NaN
# 104        ...                   0          NaN             NaN
# 108        ...                   0          NaN             NaN
# 112        ...                   0          NaN             NaN
# 116        ...                   0          NaN             NaN
# ...        ...                 ...          ...             ...
# 211592     ...                 NaN          NaN             NaN
# 211596     ...                 NaN          NaN             NaN
# 211600     ...                 NaN          NaN             NaN
# 211604     ...                 NaN          NaN               0
# 211608     ...                 NaN          NaN               0
# 211612     ...                 NaN          NaN               0
# 211616     ...                 NaN          NaN             NaN
# 211620     ...                 NaN          NaN             NaN
# 211624     ...                 NaN          NaN             NaN
# 211628     ...                 NaN          NaN             NaN
# 211632     ...                 NaN          NaN             NaN
# 211636     ...                 NaN          NaN             NaN
# 211640     ...                 NaN          NaN             NaN
# 211644     ...                 NaN          NaN             NaN
# 211648     ...                 NaN          NaN             NaN
# 211652     ...                 NaN          NaN             NaN
# 211656     ...                 NaN          NaN               0
# 211660     ...                 NaN          NaN               0
# 211664     ...                 NaN          NaN               0
# 211668     ...                 NaN          NaN             NaN
# 211672     ...                 NaN          NaN             NaN
# 211676     ...                 NaN          NaN             NaN
# 211680     ...                 NaN          NaN             NaN
# 211684     ...                 NaN          NaN             NaN
# 211688     ...                 NaN          NaN             NaN
# 211692     ...                 NaN          NaN             NaN
# 211696     ...                 NaN          NaN             NaN
# 211700     ...                 NaN          NaN             NaN
# 211704     ...                 NaN          NaN             NaN
# 211708     ...                 NaN          NaN             NaN
#
#         boardgameaccessory  wargames  thematic  arcade  cgs  videogame  \
# 0                      NaN       NaN         0     NaN  NaN        NaN
# 4                      NaN       NaN         0     NaN  NaN        NaN
# 8                      NaN       NaN       NaN     NaN  NaN        NaN
# 12                     NaN       NaN       NaN     NaN  NaN        NaN
# 16                     NaN         0       NaN     NaN  NaN        NaN
# 20                     NaN       NaN         0     NaN  NaN        NaN
# 24                     NaN       NaN       NaN     NaN  NaN        NaN
# 28                     NaN       NaN       NaN     NaN  NaN        NaN
# 32                     NaN       NaN       NaN     NaN  NaN        NaN
# 36                     NaN       NaN       NaN     NaN  NaN        NaN
# 40                     NaN       NaN       NaN     NaN  NaN        NaN
# 44                     NaN       NaN         0     NaN  NaN        NaN
# 48                     NaN       NaN       NaN     NaN  NaN        NaN
# 52                     NaN       NaN       NaN     NaN  NaN        NaN
# 56                     NaN       NaN         0     NaN  NaN        NaN
# 60                     NaN       NaN         0     NaN  NaN        NaN
# 64                     NaN       NaN       NaN     NaN  NaN        NaN
# 68                     NaN       NaN       NaN     NaN  NaN        NaN
# 72                     NaN       NaN       NaN     NaN  NaN        NaN
# 76                     NaN       NaN       NaN     NaN  NaN        NaN
# 80                     NaN       NaN         0     NaN    0        NaN
# 84                     NaN       NaN       NaN     NaN  NaN        NaN
# 88                     NaN       NaN       NaN     NaN  NaN        NaN
# 92                     NaN       NaN         0     NaN  NaN        NaN
# 96                     NaN       NaN       NaN     NaN  NaN        NaN
# 100                    NaN       NaN         0     NaN  NaN        NaN
# 104                    NaN       NaN       NaN     NaN  NaN        NaN
# 108                    NaN       NaN       NaN     NaN  NaN        NaN
# 112                    NaN       NaN       NaN     NaN  NaN        NaN
# 116                    NaN       NaN       NaN     NaN  NaN        NaN
# ...                    ...       ...       ...     ...  ...        ...
# 211592                 NaN         0       NaN     NaN  NaN        NaN
# 211596                 NaN       NaN       NaN     NaN  NaN        NaN
# 211600                 NaN       NaN       NaN     NaN  NaN        NaN
# 211604                 NaN       NaN       NaN     NaN  NaN        NaN
# 211608                 NaN       NaN       NaN     NaN  NaN        NaN
# 211612                 NaN       NaN       NaN     NaN  NaN        NaN
# 211616                 NaN       NaN       NaN     NaN  NaN        NaN
# 211620                 NaN         0       NaN     NaN  NaN        NaN
# 211624                 NaN         0       NaN     NaN  NaN        NaN
# 211628                 NaN       NaN       NaN     NaN  NaN        NaN
# 211632                 NaN       NaN       NaN     NaN  NaN        NaN
# 211636                 NaN       NaN       NaN     NaN  NaN        NaN
# 211640                 NaN         0       NaN     NaN  NaN        NaN
# 211644                 NaN       NaN       NaN     NaN  NaN        NaN
# 211648                 NaN       NaN       NaN     NaN  NaN        NaN
# 211652                 NaN       NaN       NaN     NaN  NaN        NaN
# 211656                 NaN       NaN       NaN     NaN  NaN        NaN
# 211660                 NaN       NaN       NaN     NaN  NaN        NaN
# 211664                 NaN       NaN       NaN     NaN  NaN        NaN
# 211668                 NaN       NaN       NaN     NaN  NaN        NaN
# 211672                 NaN       NaN       NaN     NaN  NaN        NaN
# 211676                 NaN       NaN       NaN     NaN  NaN        NaN
# 211680                 NaN       NaN       NaN     NaN  NaN        NaN
# 211684                 NaN       NaN       NaN     NaN  NaN        NaN
# 211688                 NaN         0       NaN     NaN  NaN        NaN
# 211692                 NaN       NaN       NaN     NaN  NaN        NaN
# 211696                 NaN         0       NaN     NaN  NaN        NaN
# 211700                 NaN       NaN       NaN     NaN  NaN        NaN
# 211704                 NaN       NaN       NaN     NaN  NaN        NaN
# 211708                 NaN       NaN       NaN     NaN  NaN        NaN
#
#         commodore64
# 0               NaN
# 4               NaN
# 8               NaN
# 12              NaN
# 16              NaN
# 20              NaN
# 24              NaN
# 28              NaN
# 32              NaN
# 36              NaN
# 40              NaN
# 44              NaN
# 48              NaN
# 52              NaN
# 56              NaN
# 60              NaN
# 64              NaN
# 68              NaN
# 72              NaN
# 76              NaN
# 80              NaN
# 84              NaN
# 88              NaN
# 92              NaN
# 96              NaN
# 100             NaN
# 104             NaN
# 108             NaN
# 112             NaN
# 116             NaN
# ...             ...
# 211592          NaN
# 211596          NaN
# 211600          NaN
# 211604          NaN
# 211608          NaN
# 211612          NaN
# 211616          NaN
# 211620          NaN
# 211624          NaN
# 211628          NaN
# 211632          NaN
# 211636          NaN
# 211640          NaN
# 211644          NaN
# 211648          NaN
# 211652          NaN
# 211656          NaN
# 211660          NaN
# 211664          NaN
# 211668          NaN
# 211672          NaN
# 211676          NaN
# 211680          NaN
# 211684          NaN
# 211688          NaN
# 211692          NaN
# 211696          NaN
# 211700          NaN
# 211704          NaN
# 211708          NaN
#
# [52736 rows x 39 columns]

# %%
### Category Function
def cast_merge_by_class(grouping, fill_term, lst, bg_df):
    all_terms_grouping = [getattr(i, grouping) for i in lst]
    unique_terms_grouping = list(set([i for j in all_terms_grouping for i in j]))
    grouping_term_columns = ['Name', 'ID'] + [fill_term + s for s in unique_terms_grouping]
    grouping_term_columns = [re.sub(' ', '_', x) for x in grouping_term_columns]

    major_grouping_df = pd.DataFrame(columns = grouping_term_columns)

    for game in progressbar.log_progress(lst, 'Scanning list'):
        minor_grouping_df = pd.DataFrame(columns = grouping_term_columns, index=[0])
        minor_grouping_df = minor_grouping_df.fillna(False)
        minor_grouping_df['Name'] = game.name
        minor_grouping_df['ID'] = game.id
        for entry in getattr(game, grouping):
            term = fill_term + re.sub(' ', '_', entry)
            minor_grouping_df[term] = True

        major_grouping_df = major_grouping_df.append(minor_grouping_df)

    # global bg_df
    df_out = pd.merge(df, major_grouping_df, on = ['Name', 'ID'])
    return(df_out)

# %%
merge_pairs = {'mechanics':'Mechanic_', 'categories':'Category_'}

for key in progressbar.log_progress(merge_pairs.keys(), 'Casting Classes'):
    bg_dfbg_df = cast_merge_by_class(key, merge_pairs[key], flatted_list, bg_df)
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=2)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))
# VBox(children=(HTML(value=''), IntProgress(value=0, max=105600)))

# %% [markdown]
# ## Remove duplicates

# %%
bg_dfbg_df = bg_df.drop_duplicates(keep='first')
bg_df
# Out:
#                                                      Name      ID  \
# 0                                              Gloomhaven  174430
# 4                               Pandemic Legacy: Season 1  161936
# 8           Through the Ages: A New Story of Civilization  182028
# 12                                      Terraforming Mars  167791
# 16                                      Twilight Struggle   12333
# 20                                   Star Wars: Rebellion  187645
# 24                                           Gaia Project  220308
# 28                                                 Scythe  169786
# 32                                    Great Western Trail  193738
# 36                     Twilight Imperium (Fourth Edition)  233078
# 40                                          Terra Mystica  120677
# 44                       War of the Ring (Second Edition)  115746
# 48                                The Castles of Burgundy   84876
# 52                                         7 Wonders Duel  173346
# 56                                          Spirit Island  162886
# 60                                      The 7th Continent  180263
# 64                                      Brass: Birmingham  224517
# 68                          Viticulture Essential Edition  183394
# 72                                            Puerto Rico    3076
# 76                                              Concordia  124361
# 80                           Arkham Horror: The Card Game  205637
# 84                              Caverna: The Cave Farmers  102794
# 88                                      Brass: Lancashire   28720
# 92                                 Mage Knight Board Game   96848
# 96                                               Agricola   31260
# 100                   Mansions of Madness: Second Edition  205059
# 104                                               Orléans  164928
# 108                                      A Feast for Odin  177736
# 112                                            Blood Rage  170216
# 116                                    Food Chain Magnate  175914
# ...                                                   ...     ...
# 211592                                             Ritual   68009
# 211596          Basic Action Super Heroes! Sci-Fi Edition   68017
# 211600                                    Five Star Final   68024
# 211604                                  Felix Farbenschaf   68030
# 211608                    Rechen-Piraten: Das Kartenspiel   68031
# 211612                                   Verhext nochmal!   68032
# 211616                           Dragon War: Gateways Set   68038
# 211620                                      Sword of Fire   68039
# 211624                                  Battle for Korsun   68046
# 211628                                         Dice Floor   68057
# 211632                                Star Fleet Scramble   68063
# 211636                 Battlefield Evolution: Pacific War   68065
# 211640                                  Finnish Civil War   68072
# 211644                                    Behind the Lens   68079
# 211648                                   Squiggle Connect   68084
# 211652                                               Gibs   68086
# 211656                                   Doubloon Dippity   68088
# 211660                                       Sink or Swim   68089
# 211664                                      Bed of Pearls   68092
# 211668                              Rolaweel Three in One   68094
# 211672                             Giggles Game of Action   68095
# 211676                                      Monkey Shines   68096
# 211680                                        Pizza Party   68097
# 211684                                       O' PenzedoR!   68104
# 211688  Armoured Wargaming: A Detailed Guide to Model ...   68106
# 211692             Super Sadistic Advanced Empire Builder   68119
# 211696                                     ASL Annual '92   68122
# 211700                                Assault of the Dead   68137
# 211704                              The Green and The Tan   68138
# 211708                                 UNO: Kung Fu Panda   68140
#
#                                 Publisher  Minimum Players  Max Players  \
# 0                       Cephalofair Games                1            4
# 4                       Z-Man Games, Inc.                2            4
# 8                     Czech Games Edition                2            4
# 12                              FryxGames                1            5
# 16                              GMT Games                2            2
# 20                   Fantasy Flight Games                2            4
# 24                       Feuerland Spiele                1            4
# 28                       Stonemaier Games                1            5
# 32                           eggertspiele                2            4
# 36                   Fantasy Flight Games                3            6
# 40                       Feuerland Spiele                2            5
# 44                             Ares Games                2            4
# 48                                   alea                2            4
# 52                       Repos Production                2            2
# 56      Greater Than Games (Fabled Nexus)                1            4
# 60                          Serious Poulp                1            4
# 64                                 Roxley                2            4
# 68                       Stonemaier Games                1            6
# 72                                   alea                3            5
# 76                              PD-Verlag                2            5
# 80                   Fantasy Flight Games                1            2
# 84                          Lookout Games                1            7
# 88                                 Roxley                2            4
# 92                                WizKids                1            4
# 96                          Lookout Games                1            5
# 100                  Fantasy Flight Games                1            5
# 104                             dlp games                2            4
# 108                      Feuerland Spiele                1            4
# 112                          CMON Limited                2            4
# 116                      Splotter Spellen                2            5
# ...                                   ...              ...          ...
# 211592                   (Self-Published)                2            0
# 211596                 Basic Action Games                0            0
# 211600                     Milton Bradley                0            5
# 211604                               HABA                2            4
# 211608                               HABA                2            4
# 211612                               HABA                2            4
# 211616                       RAK Graphics                2            6
# 211620                   (Self-Published)                2            2
# 211624                       Banana Games                2            2
# 211628                    (Web published)                2            3
# 211632                        nestorgames                2            2
# 211636                Mongoose Publishing                2            0
# 211640                   (Self-Published)                2            2
# 211644                          (Unknown)                1            0
# 211648                   RandomLine, Inc.                3            6
# 211652              The Game Crafter, LLC                2            5
# 211656                    Funhub Creative                2           10
# 211660                    Funhub Creative                2            4
# 211664                    Funhub Creative                2            4
# 211668                    Rosebud Art Co.                2            0
# 211672                    Rosebud Art Co.                1            0
# 211676        E. E. Fairchild Corporation                2            0
# 211680        Ideal School Supply Company                2            6
# 211684                      Pavillon Noir                3            5
# 211688           Patrick Stephens Limited                2            0
# 211692                   (Self-Published)                2            8
# 211696            The Avalon Hill Game Co                2            2
# 211700                   (Self-Published)                3            5
# 211704                   (Self-Published)                2            2
# 211708                             Mattel                2           10
#
#         Num_Ratings  Avg_Rating  Bayes_Avg_Rating  Avg_Weight  StDev_Rating  \
# 0             23504     8.91228           8.61315      3.7753      1.601920
# 4             30370     8.64675           8.49226      2.8318      1.612030
# 8             15179     8.54243           8.26341      4.3657      1.491370
# 12            36736     8.40232           8.23708      3.2313      1.358540
# 16            33857     8.32508           8.17631      3.5645      1.587340
# 20            16091     8.44952           8.16307      3.6729      1.377980
# 24             8593     8.56949           8.12296      4.3012      1.421250
# 28            37941     8.29311           8.12183      3.3705      1.420140
# 32            18302     8.28808           8.07636      3.6909      1.251350
# 36             6021     8.75469           8.06175      4.1752      1.535010
# 40            32077     8.19957           8.05233      3.9480      1.466770
# 44             9544     8.41695           8.02285      4.0564      1.538680
# 48            35851     8.13015           8.01235      3.0166      1.240730
# 52            39272     8.12677           7.99285      2.2297      1.163660
# 56             9757     8.38891           7.97867      3.9373      1.446270
# 60             8631     8.44554           7.95344      2.8659      1.593960
# 64             4815     8.63405           7.95232      3.8739      1.156050
# 68            16594     8.14955           7.92658      2.9222      1.241430
# 72            55810     8.04083           7.92631      3.2898      1.383100
# 76            19150     8.09685           7.92118      3.0876      1.188640
# 80            16664     8.22791           7.92054      3.3077      1.431470
# 84            23243     8.07825           7.91289      3.7873      1.352860
# 88            14647     8.11884           7.90638      3.8745      1.394450
# 92            23163     8.10591           7.89416      4.2635      1.617260
# 96            56402     7.99436           7.89228      3.6355      1.565990
# 100           15928     8.16405           7.88022      2.6678      1.433350
# 104           15394     8.08563           7.87587      3.0802      1.163920
# 108           10642     8.17832           7.85340      3.8229      1.347030
# 112           24863     8.03803           7.85112      2.8875      1.396530
# 116            9311     8.18605           7.84970      4.1957      1.546400
# ...             ...         ...               ...         ...           ...
# 211592            3     5.83333           0.00000      2.0000      3.423770
# 211596            0     0.00000           0.00000      0.0000      0.000000
# 211600            0     0.00000           0.00000      0.0000      0.000000
# 211604            7     6.27143           0.00000      1.0000      1.562700
# 211608            3     6.33333           0.00000      0.0000      0.471405
# 211612            3     3.00000           0.00000      0.0000      0.816497
# 211616            0     0.00000           0.00000      0.0000      0.000000
# 211620            4     5.50000           0.00000      1.0000      2.958040
# 211624            9     6.83333           0.00000      1.2500      1.763830
# 211628            2     6.00000           0.00000      2.0000      0.000000
# 211632            8     7.06250           0.00000      2.0000      1.073470
# 211636            3     7.66667           0.00000      0.0000      0.471405
# 211640           11     7.31818           0.00000      2.0000      0.805457
# 211644            0     0.00000           0.00000      0.0000      0.000000
# 211648            0     0.00000           0.00000      0.0000      0.000000
# 211652            2     7.75000           0.00000      1.0000      2.250000
# 211656            3     1.16667           0.00000      1.0000      0.235702
# 211660            6     3.16667           0.00000      1.0000      2.192160
# 211664            3     4.00000           0.00000      1.0000      2.160250
# 211668            0     0.00000           0.00000      0.0000      0.000000
# 211672            0     0.00000           0.00000      0.0000      0.000000
# 211676            0     0.00000           0.00000      0.0000      0.000000
# 211680            2     4.75000           0.00000      0.0000      0.250000
# 211684           12     5.20833           0.00000      1.0000      1.613210
# 211688            1     7.00000           0.00000      0.0000      0.000000
# 211692            0     0.00000           0.00000      0.0000      0.000000
# 211696           54     7.75926           5.59330      4.7143      1.635090
# 211700            0     0.00000           0.00000      3.0000      0.000000
# 211704            1     5.50000           0.00000      0.0000      0.000000
# 211708            4     5.00000           0.00000      0.0000      1.224740
#
#                ...          Category_Educational  Category_Travel  \
# 0              ...                         False            False
# 4              ...                         False            False
# 8              ...                         False            False
# 12             ...                         False            False
# 16             ...                         False            False
# 20             ...                         False            False
# 24             ...                         False            False
# 28             ...                         False            False
# 32             ...                         False            False
# 36             ...                         False            False
# 40             ...                         False            False
# 44             ...                         False            False
# 48             ...                         False            False
# 52             ...                         False            False
# 56             ...                         False            False
# 60             ...                         False            False
# 64             ...                         False            False
# 68             ...                         False            False
# 72             ...                         False            False
# 76             ...                         False            False
# 80             ...                         False            False
# 84             ...                         False            False
# 88             ...                         False            False
# 92             ...                         False            False
# 96             ...                         False            False
# 100            ...                         False            False
# 104            ...                         False             True
# 108            ...                         False            False
# 112            ...                         False            False
# 116            ...                         False            False
# ...            ...                           ...              ...
# 211592         ...                         False            False
# 211596         ...                         False            False
# 211600         ...                         False            False
# 211604         ...                         False            False
# 211608         ...                          True            False
# 211612         ...                         False            False
# 211616         ...                         False            False
# 211620         ...                         False            False
# 211624         ...                         False            False
# 211628         ...                         False            False
# 211632         ...                         False            False
# 211636         ...                         False            False
# 211640         ...                         False            False
# 211644         ...                         False            False
# 211648         ...                         False            False
# 211652         ...                         False            False
# 211656         ...                         False            False
# 211660         ...                         False            False
# 211664         ...                         False            False
# 211668         ...                         False            False
# 211672         ...                         False            False
# 211676         ...                         False            False
# 211680         ...                          True            False
# 211684         ...                         False            False
# 211688         ...                         False            False
# 211692         ...                         False            False
# 211696         ...                         False            False
# 211700         ...                         False            False
# 211704         ...                         False            False
# 211708         ...                         False            False
#
#         Category_Industry_/_Manufacturing  Category_Farming  \
# 0                                   False             False
# 4                                   False             False
# 8                                   False             False
# 12                                   True             False
# 16                                  False             False
# 20                                  False             False
# 24                                  False             False
# 28                                  False             False
# 32                                  False             False
# 36                                  False             False
# 40                                  False             False
# 44                                  False             False
# 48                                  False             False
# 52                                  False             False
# 56                                  False             False
# 60                                  False             False
# 64                                   True             False
# 68                                  False              True
# 72                                  False              True
# 76                                  False             False
# 80                                  False             False
# 84                                  False              True
# 88                                   True             False
# 92                                  False             False
# 96                                  False              True
# 100                                 False             False
# 104                                 False             False
# 108                                  True             False
# 112                                 False             False
# 116                                  True             False
# ...                                   ...               ...
# 211592                              False             False
# 211596                              False             False
# 211600                              False             False
# 211604                              False             False
# 211608                              False             False
# 211612                              False             False
# 211616                              False             False
# 211620                              False             False
# 211624                              False             False
# 211628                              False             False
# 211632                              False             False
# 211636                              False             False
# 211640                              False             False
# 211644                              False             False
# 211648                              False             False
# 211652                              False             False
# 211656                              False             False
# 211660                              False             False
# 211664                              False             False
# 211668                              False             False
# 211672                              False             False
# 211676                              False             False
# 211680                              False             False
# 211684                              False             False
# 211688                              False             False
# 211692                              False             False
# 211696                              False             False
# 211700                              False             False
# 211704                              False             False
# 211708                              False             False
#
#         Category_Adventure  Category_Religious  Category_Transportation  \
# 0                     True               False                    False
# 4                    False               False                    False
# 8                    False               False                    False
# 12                   False               False                    False
# 16                   False               False                    False
# 20                   False               False                    False
# 24                   False               False                    False
# 28                   False               False                    False
# 32                   False               False                    False
# 36                   False               False                    False
# 40                   False               False                    False
# 44                    True               False                    False
# 48                   False               False                    False
# 52                   False               False                    False
# 56                   False               False                    False
# 60                    True               False                    False
# 64                   False               False                     True
# 68                   False               False                    False
# 72                   False               False                    False
# 76                   False               False                    False
# 80                    True               False                    False
# 84                   False               False                    False
# 88                   False               False                     True
# 92                    True               False                    False
# 96                   False               False                    False
# 100                   True               False                    False
# 104                  False                True                    False
# 108                  False               False                    False
# 112                  False               False                    False
# 116                  False               False                    False
# ...                    ...                 ...                      ...
# 211592               False               False                    False
# 211596               False               False                    False
# 211600               False               False                    False
# 211604               False               False                    False
# 211608               False               False                    False
# 211612               False               False                    False
# 211616               False               False                    False
# 211620               False               False                    False
# 211624               False               False                    False
# 211628               False               False                    False
# 211632               False               False                    False
# 211636               False               False                    False
# 211640               False               False                    False
# 211644               False               False                    False
# 211648               False               False                    False
# 211652               False               False                    False
# 211656               False               False                    False
# 211660               False               False                    False
# 211664               False               False                    False
# 211668               False               False                    False
# 211672               False               False                    False
# 211676               False               False                    False
# 211680               False               False                    False
# 211684               False               False                    False
# 211688               False               False                    False
# 211692               False               False                     True
# 211696               False               False                    False
# 211700               False               False                    False
# 211704               False               False                    False
# 211708               False               False                    False
#
#         Category_Murder/Mystery  Category_Age_of_Reason  Category_Deduction
# 0                         False                   False               False
# 4                         False                   False               False
# 8                         False                   False               False
# 12                        False                   False               False
# 16                        False                   False               False
# 20                        False                   False               False
# 24                        False                   False               False
# 28                        False                   False               False
# 32                        False                   False               False
# 36                        False                   False               False
# 40                        False                   False               False
# 44                        False                   False               False
# 48                        False                   False               False
# 52                        False                   False               False
# 56                        False                    True               False
# 60                        False                   False               False
# 64                        False                   False               False
# 68                        False                   False               False
# 72                        False                   False               False
# 76                        False                   False               False
# 80                        False                   False               False
# 84                        False                   False               False
# 88                        False                   False               False
# 92                        False                   False               False
# 96                        False                   False               False
# 100                        True                   False               False
# 104                       False                   False               False
# 108                       False                   False               False
# 112                       False                   False               False
# 116                       False                   False               False
# ...                         ...                     ...                 ...
# 211592                    False                   False               False
# 211596                    False                   False               False
# 211600                    False                   False               False
# 211604                    False                   False               False
# 211608                    False                   False               False
# 211612                    False                   False               False
# 211616                    False                   False               False
# 211620                    False                   False               False
# 211624                    False                   False               False
# 211628                    False                   False               False
# 211632                    False                   False               False
# 211636                    False                   False               False
# 211640                    False                   False               False
# 211644                    False                   False                True
# 211648                    False                   False               False
# 211652                    False                   False               False
# 211656                    False                   False               False
# 211660                    False                   False               False
# 211664                    False                   False               False
# 211668                    False                   False               False
# 211672                    False                   False               False
# 211676                    False                   False               False
# 211680                    False                   False               False
# 211684                    False                   False               False
# 211688                    False                   False               False
# 211692                    False                   False               False
# 211696                    False                   False               False
# 211700                    False                   False               False
# 211704                    False                   False               False
# 211708                    False                   False               False
#
# [52736 rows x 176 columns]

# %% [markdown]
# ## Add Today to Dataframe

# %%
bg_df['Downloaded Date'] = time.strftime("%Y-%m-%d", time.gmtime(time.time()))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Saving DataFrame to File and Database

# %%
import MySQLdb
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://coolmini_gonk:G0nkG0nk@venus.coolminiornot.com:3306/coolmini_business_intelligence', echo = False)
bg_df.to_sql(name = 'BGG_Scraper', con = engine, if_exists = 'append', index = False)

# %%
total_timer_end = time.time()
print('Total elapsed time: ', time.strftime("%H:%M:%S", time.gmtime(total_timer_end-total_timer_start)))
